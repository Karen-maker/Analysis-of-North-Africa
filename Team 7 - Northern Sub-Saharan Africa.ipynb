# %%
import pandas as pd # data science essentials
import matplotlib.pyplot as plt # data visualization essentials
import seaborn as sns #  enhanced data visualization

# IMPORTING DATA RELATED To The WORLD


file = "/Users/karenlarios/Desktop/Business Analytics/finalproject/Finalproject_team7.xlsx"

# importing excel file to python
world_data = pd.read_excel( io = file,
                            sheet_name = 'Data',
                            header = 0 )


# showing WORLD data 


world_data.head(n=5)
# Out:
#   Country Code Total Country Name  \
# 0                ABW        Aruba
# 1                AFG  Afghanistan
# 2                AGO       Angola
# 3                ALB      Albania
# 4                AND      Andorra
#
#                                    Hult Region        Cool Name  \
# 0  Carribean Islands & Parts of Latin America           Ratchet
# 1                         Middle East & Russia           Mirage
# 2                           Sub-Saharan Africa        Sideswipe
# 3                               Eastern Europe  Skids & Mudflap
# 4                               Eastern Europe  Skids & Mudflap
#
#    AIDS estimated deaths (UNAIDS estimates)  \
# 0                                       NaN
# 1                                       NaN
# 2                                    9200.0
# 3                                     100.0
# 4                                       NaN
#
#    Adjusted net enrollment rate, primary (% of primary school age children)  \
# ...

# %%
# IMPORTING DATA RELATED TO TEAM 7 REGION


file = "/Users/karenlarios/Desktop/Business Analytics/finalproject/Finalproject_team7.xlsx"

# importing excel file to python
sub_saharan_africa = pd.read_excel( io         = file,
                                    sheet_name = 'Data',
                                    header     = 0)


# showing data for our region based on Cool Name assigned to Team 7
cleaned_data_team7 = sub_saharan_africa.loc[ : , : ][sub_saharan_africa.loc[ : , 'Cool Name'] == 'Bumblebee']
cleaned_data_team7
# Out:
#     Country Code Total      Country Name                  Hult Region  \
# 54                 DZA           Algeria  Northern Sub-Saharan Africa
# 56                 EGY  Egypt, Arab Rep.  Northern Sub-Saharan Africa
# 109                LBY             Libya  Northern Sub-Saharan Africa
# 119                MAR           Morocco  Northern Sub-Saharan Africa
# 127                MLI              Mali  Northern Sub-Saharan Africa
# 134                MRT        Mauritania  Northern Sub-Saharan Africa
# 140                NER             Niger  Northern Sub-Saharan Africa
# 167                SDN             Sudan  Northern Sub-Saharan Africa
# 187                TCD              Chad  Northern Sub-Saharan Africa
# 195                TUN           Tunisia  Northern Sub-Saharan Africa
#
#      Cool Name  AIDS estimated deaths (UNAIDS estimates)  \
# 54   Bumblebee                                     200.0
# 56   Bumblebee                                     500.0
# ...

# %%
# Change column names for easy reference

world_data.columns         = ['Code', 'Country','Region', 'Cool Name', 'AIDS deaths', '% of primary school children','Adolescent fertility rate','% of people living with HIV','Births attended by skilled health staff','CO2 emissions','% of female employment','% of male employment','% of total employment','Employment to population ratio, 15+, female ','Employment to population ratio, 15+, male ','Employment to population ratio, 15+, total','Energy use per $1,000 GDP ','Fertility rate','GDP per person employed','GDP per unit of energy use','GNI per capita','Immunization','Improved sanitation facilities','Improved water source','Tuberculosis','Income share held by lowest 20%','Internet users','Life expectancy','Literacy rate  adult','Maternal mortality ratio','Cellular subscriptions','Mortality rate infant','Net ODA','Population','Poverty gap','Women in prenatal care','% of HIV','% of undernourishment','Primary completion rate', 'Seats held by women in parliament','Malaria','School enrollment','Self-employed','Trade','Tuberculosis']
cleaned_data_team7.columns = ['Code', 'Country','Region', 'Cool Name', 'AIDS deaths', '% of primary school children','Adolescent fertility rate','% of people living with HIV','Births attended by skilled health staff','CO2 emissions','% of female employment','% of male employment','% of total employment','Employment to population ratio, 15+, female ','Employment to population ratio, 15+, male ','Employment to population ratio, 15+, total','Energy use per $1,000 GDP ','Fertility rate','GDP per person employed','GDP per unit of energy use','GNI per capita','Immunization','Improved sanitation facilities','Improved water source','Tuberculosis','Income share held by lowest 20%','Internet users','Life expectancy','Literacy rate  adult','Maternal mortality ratio','Cellular subscriptions','Mortality rate infant','Net ODA','Population','Poverty gap','Women in prenatal care','% of HIV','% of undernourishment','Primary completion rate', 'Seats held by women in parliament','Malaria','School enrollment','Self-employed','Trade','Tuberculosis']

# To check the new columns name
print(f""" 
The new columns name for the REGION data are:


{cleaned_data_team7.columns}""")

# To check the new columns name
print(f""" 



The new columns name for the WORLD data are:


{world_data.columns}""")
# Out:
#
# The new columns name for the REGION data are:
#
#
# Index(['Code', 'Country', 'Region', 'Cool Name', 'AIDS deaths',
#        '% of primary school children', 'Adolescent fertility rate',
#        '% of people living with HIV',
#        'Births attended by skilled health staff', 'CO2 emissions',
#        '% of female employment', '% of male employment',
#        '% of total employment', 'Employment to population ratio, 15+, female ',
#        'Employment to population ratio, 15+, male ',
#        'Employment to population ratio, 15+, total',
#        'Energy use per $1,000 GDP ', 'Fertility rate',
#        'GDP per person employed', 'GDP per unit of energy use',
#        'GNI per capita', 'Immunization', 'Improved sanitation facilities',
#        'Improved water source', 'Tuberculosis',
#        'Income share held by lowest 20%', 'Internet users', 'Life expectancy',
#        'Literacy rate  adult', 'Maternal mortality ratio',
# ...

# %%
# Checking if data type needs to be changed

cleaned_data_team7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 54 to 195
# Data columns (total 45 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Code                                          10 non-null     object
#  1   Country                                       10 non-null     object
#  2   Region                                        10 non-null     object
#  3   Cool Name                                     10 non-null     object
#  4   AIDS deaths                                   9 non-null      float64
#  5   % of primary school children                  5 non-null      float64
#  6   Adolescent fertility rate                     10 non-null     float64
#  7   % of people living with HIV                   9 non-null      float64
#  8   Births attended by skilled health staff       2 non-null      float64
# ...

# %%
# WORLD CHECK: Detecting missing values for each column using Method Chaining

world_data.isnull().sum(axis = 0)
# Out:
# Code                                              0
# Country                                           0
# Region                                            0
# Cool Name                                         0
# AIDS deaths                                      85
# % of primary school children                     86
# Adolescent fertility rate                        23
# % of people living with HIV                      81
# Births attended by skilled health staff         115
# CO2 emissions                                    13
# % of female employment                           30
# % of male employment                             30
# % of total employment                            30
# Employment to population ratio, 15+, female      30
# Employment to population ratio, 15+, male        30
# Employment to population ratio, 15+, total       30
# Energy use per $1,000 GDP                        80
# Fertility rate                                   15
# ...

# %%
# WORLD CHECK: Number of missing values as a percentage of total observations per column

world_data.isnull().mean(axis = 0).round(decimals = 2)
# Out:
# Code                                            0.00
# Country                                         0.00
# Region                                          0.00
# Cool Name                                       0.00
# AIDS deaths                                     0.39
# % of primary school children                    0.40
# Adolescent fertility rate                       0.11
# % of people living with HIV                     0.37
# Births attended by skilled health staff         0.53
# CO2 emissions                                   0.06
# % of female employment                          0.14
# % of male employment                            0.14
# % of total employment                           0.14
# Employment to population ratio, 15+, female     0.14
# Employment to population ratio, 15+, male       0.14
# Employment to population ratio, 15+, total      0.14
# Energy use per $1,000 GDP                       0.37
# Fertility rate                                  0.07
# ...

# %%
# REGIONAL CHECK: Detecting missing values for each column using Method Chaining

cleaned_data_team7.isnull().sum(axis = 0)
# Out:
# Code                                            0
# Country                                         0
# Region                                          0
# Cool Name                                       0
# AIDS deaths                                     1
# % of primary school children                    5
# Adolescent fertility rate                       0
# % of people living with HIV                     1
# Births attended by skilled health staff         8
# CO2 emissions                                   0
# % of female employment                          0
# % of male employment                            0
# % of total employment                           0
# Employment to population ratio, 15+, female     0
# Employment to population ratio, 15+, male       0
# Employment to population ratio, 15+, total      0
# Energy use per $1,000 GDP                       3
# Fertility rate                                  0
# GDP per person employed                         0
# ...

# %%
# REGIONAL CHECK : Number of missing values as a percentage of total observations per column

cleaned_data_team7.isnull().mean(axis = 0).round(decimals = 2)
# Out:
# Code                                            0.0
# Country                                         0.0
# Region                                          0.0
# Cool Name                                       0.0
# AIDS deaths                                     0.1
# % of primary school children                    0.5
# Adolescent fertility rate                       0.0
# % of people living with HIV                     0.1
# Births attended by skilled health staff         0.8
# CO2 emissions                                   0.0
# % of female employment                          0.0
# % of male employment                            0.0
# % of total employment                           0.0
# Employment to population ratio, 15+, female     0.0
# Employment to population ratio, 15+, male       0.0
# Employment to population ratio, 15+, total      0.0
# Energy use per $1,000 GDP                       0.3
# Fertility rate                                  0.0
# ...

# %%
# Flagging missing values

# Developing a loop to automatically flag missing values for column in sub_saharan_africa

#for col in cleaned_data_team7:
    
    #if cleaned_data_team7[col].isnull().astype(int).sum() > 0:
        #cleaned_data_team7['m_'+ col] = cleaned_data_team7[col].isnull().astype(int)
        
        
cleaned_data_team7['m_AIDS deaths'] = cleaned_data_team7['AIDS deaths'].isnull().astype(int)       
cleaned_data_team7['m_% of primary school children'] = cleaned_data_team7['% of primary school children'].isnull().astype(int) 
cleaned_data_team7['m_% of people living with HIV'] = cleaned_data_team7['% of people living with HIV'].isnull().astype(int) 
cleaned_data_team7['m_Births attended by skilled health staff'] = cleaned_data_team7['Births attended by skilled health staff'].isnull().astype(int) 
cleaned_data_team7['m_Energy use per $1,000 GDP '] = cleaned_data_team7['Energy use per $1,000 GDP '].isnull().astype(int) 
cleaned_data_team7['m_GDP per unit of energy use'] = cleaned_data_team7['GDP per unit of energy use'].isnull().astype(int) 
cleaned_data_team7['m_Improved water source'] = cleaned_data_team7['Improved water source'].isnull().astype(int) 
cleaned_data_team7['m_Income share held by lowest 20%'] = cleaned_data_team7['Income share held by lowest 20%'].isnull().astype(int) 
cleaned_data_team7['m_Internet users'] = cleaned_data_team7['Internet users'].isnull().astype(int) 
cleaned_data_team7['m_Literacy rate  adult'] = cleaned_data_team7['Literacy rate  adult'].isnull().astype(int) 
cleaned_data_team7['m_Poverty gap'] = cleaned_data_team7['Poverty gap'].isnull().astype(int) 
cleaned_data_team7['m_Women in prenatal care'] = cleaned_data_team7['Women in prenatal care'].isnull().astype(int)                         
cleaned_data_team7['m_% of HIV'] = cleaned_data_team7['% of HIV'].isnull().astype(int)    
cleaned_data_team7['m_% of undernourishment'] = cleaned_data_team7['% of undernourishment'].isnull().astype(int) 
cleaned_data_team7['m_Primary completion rate'] = cleaned_data_team7['Primary completion rate'].isnull().astype(int) 
cleaned_data_team7['m_Malaria'] = cleaned_data_team7['Malaria'].isnull().astype(int)                               
cleaned_data_team7['m_School enrollment'] = cleaned_data_team7['School enrollment'].isnull().astype(int)
# Out:
# <ipython-input-10-611ae754e118>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data_team7['m_AIDS deaths'] = cleaned_data_team7['AIDS deaths'].isnull().astype(int)
# <ipython-input-10-611ae754e118>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data_team7['m_% of primary school children'] = cleaned_data_team7['% of primary school children'].isnull().astype(int)
# <ipython-input-10-611ae754e118>:13: SettingWithCopyWarning:
# ...

# %%
# Printing the columns to check which columns were added


print(f"""{cleaned_data_team7.iloc[ : , -17 : ].sum(axis = 0)}""")
# Out:
# m_AIDS deaths                                1
# m_% of primary school children               5
# m_% of people living with HIV                1
# m_Births attended by skilled health staff    8
# m_Energy use per $1,000 GDP                  3
# m_GDP per unit of energy use                 3
# m_Improved water source                      1
# m_Income share held by lowest 20%            8
# m_Internet users                             1
# m_Literacy rate  adult                       6
# m_Poverty gap                                9
# m_Women in prenatal care                     8
# m_% of HIV                                   1
# m_% of undernourishment                      2
# m_Primary completion rate                    5
# m_Malaria                                    5
# m_School enrollment                          5
# dtype: int64

# %%
# Creating a column to sum missing value flags
cleaned_data_team7['mv_sum'] = cleaned_data_team7['m_AIDS deaths']                             + \
                               cleaned_data_team7['m_% of primary school children']            + \
                               cleaned_data_team7['m_% of people living with HIV']             + \
                               cleaned_data_team7['m_Births attended by skilled health staff'] + \
                               cleaned_data_team7['m_Energy use per $1,000 GDP ']               + \
                               cleaned_data_team7['m_GDP per unit of energy use']              + \
                               cleaned_data_team7['m_Improved water source']                   + \
                               cleaned_data_team7['m_Income share held by lowest 20%']         + \
                               cleaned_data_team7['m_Internet users']                          + \
                               cleaned_data_team7['m_Literacy rate  adult']                    + \
                               cleaned_data_team7['m_Poverty gap']                             + \
                               cleaned_data_team7['m_Women in prenatal care']                  + \
                               cleaned_data_team7['m_% of HIV']                                + \
                               cleaned_data_team7['m_% of undernourishment']                   + \
                               cleaned_data_team7['m_Primary completion rate']                 + \
                               cleaned_data_team7['m_Malaria']                                 + \
                               cleaned_data_team7['m_School enrollment']               




# checking results
print(f"""

Number of Missing Values per Observation (Pct)
----------------------------------------------
{(cleaned_data_team7['mv_sum'].value_counts(normalize = True,
                                            sort      = True,
                                            ascending = True)*100).round(decimals = 2)}
""")
# Out:
# Number of Missing Values per Observation (Pct)
# ----------------------------------------------
# 4     10.0
# 9     10.0
# 12    10.0
# 6     20.0
# 10    20.0
# 5     30.0
# Name: mv_sum, dtype: float64
# <ipython-input-12-0febd6a42e80>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data_team7['mv_sum'] = cleaned_data_team7['m_AIDS deaths']                             + \

# %%
# Imputting missing values

# Step 1: Drop missing values from the Dataset so that they don't cause undue complications when generation plots

# Making new Dataframe independent
df_dropped = pd.DataFrame.copy(cleaned_data_team7)

# Dropping missing values using dropna() for df_dropped
df_dropped = df_dropped.dropna().round(decimals = 2)

# Checking to see if all missing values have been dropped
print(df_dropped)
# Out:
# Empty DataFrame
# ...

# %%
# Visualizing Data in Python - BASED ON COLUMN #1

# setting figure size
fig, ax = plt.subplots(figsize = [8, 5])


# histogram for carat
sns.distplot(a     = (df_dropped ['Tuberculosis']),
             bins  = 'fd',   #to be changed if histogram shows gaps
             hist  = True,
             kde   = False,
             rug   = False,
             color = 'black')


# titles and labels
plt.title(label = "Distribution of AIDS deaths")
plt.xlabel(xlabel = 'AIDS deaths')
plt.ylabel(ylabel = 'Frequency')


# New: These add vertical lines to the code
plt.axvline(x = (df_dropped ['Tuberculosis']).mean(),
            color = 'red')


plt.axvline(x = (df_dropped ['Tuberculosis']).median(),
            color = 'blue')


# this adds a legend
plt.legend(labels =  ['mean', 'median'])


# these compile and display the plot so that it is formatted as expected
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-7b1391351211> in <module>
#      21
#      22 # New: These add vertical lines to the code
# ---> 23 plt.axvline(x = (df_dropped ['Tuberculosis']).mean(),
#      24             color = 'red')
#      25
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in axvline(x, ymin, ymax, **kwargs)
#    2455 @_copy_docstring_and_deprecators(Axes.axvline)
#    2456 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# ...

# %%
# setting figure size
fig, ax = plt.subplots(figsize = [8, 5])


# histogram for carat
sns.distplot(a     = cleaned_data_team7['% of total employment'],
             bins  = 'fd',   #to be changed if histogram shows gaps
             hist  = True,
             kde   = False,
             rug   = False,
             color = 'black')


# titles and labels
plt.title(label = "% of total employment")
plt.xlabel(xlabel = '%')
plt.ylabel(ylabel = 'Frequency')


# New: These add vertical lines to the code
plt.axvline(x = cleaned_data_team7['% of total employment'].mean(),
            color = 'red')


plt.axvline(x = cleaned_data_team7['% of total employment'].median(),
            color = 'blue')


# this adds a legend
plt.legend(labels =  ['mean', 'median'])


# these compile and display the plot so that it is formatted as expected
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# setting figure size
fig, ax = plt.subplots(figsize = [8, 5])


# histogram for carat
sns.distplot(a     = cleaned_data_team7['Employment to population ratio, 15+, total'],
             bins  = 3,   #to be changed if histogram shows gaps
             hist  = True,
             kde   = False,
             rug   = False,
             color = 'black')


# titles and labels
plt.title(label = "Employment to population ratio, 15+, total")
plt.xlabel(xlabel = '%')
plt.ylabel(ylabel = 'Frequency')


# New: These add vertical lines to the code
plt.axvline(x = cleaned_data_team7['Employment to population ratio, 15+, total'].mean(),
            color = 'red')


plt.axvline(x = cleaned_data_team7['Employment to population ratio, 15+, total'].median(),
            color = 'blue')


# this adds a legend
plt.legend(labels =  ['mean', 'median'])


# these compile and display the plot so that it is formatted as expected
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# setting figure size
fig, ax = plt.subplots(figsize = [8, 5])


# histogram for carat
sns.distplot(a     = cleaned_data_team7['GDP per person employed'],
             bins  = 3,   #to be changed if histogram shows gaps
             hist  = True,
             kde   = False,
             rug   = False,
             color = 'black')


# titles and labels
plt.title(label = "GDP per person employed")
plt.xlabel(xlabel = '%')
plt.ylabel(ylabel = 'Frequency')


# New: These add vertical lines to the code
plt.axvline(x = cleaned_data_team7['GDP per person employed'].mean(),
            color = 'red')


plt.axvline(x = cleaned_data_team7['GDP per person employed'].median(),
            color = 'blue')


# this adds a legend
plt.legend(labels =  ['mean', 'median'])


# these compile and display the plot so that it is formatted as expected
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# setting figure size
fig, ax = plt.subplots(figsize = [8, 5])


# histogram for carat
sns.distplot(a     = cleaned_data_team7['GNI per capita'],
             bins  = 2,   #to be changed if histogram shows gaps
             hist  = True,
             kde   = False,
             rug   = False,
             color = 'black')


# titles and labels
plt.title(label = "GNI per capita")
plt.xlabel(xlabel = '%')
plt.ylabel(ylabel = 'Frequency')


# New: These add vertical lines to the code
plt.axvline(x = cleaned_data_team7['GNI per capita'].mean(),
            color = 'red')


plt.axvline(x = cleaned_data_team7['GNI per capita'].median(),
            color = 'blue')


# this adds a legend
plt.legend(labels =  ['mean', 'median'])


# these compile and display the plot so that it is formatted as expected
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# setting figure size
fig, ax = plt.subplots(figsize = [8, 5])


# histogram for carat
sns.distplot(a     = cleaned_data_team7['Immunization'],
             bins  = 'fd',   #to be changed if histogram shows gaps
             hist  = True,
             kde   = False,
             rug   = False,
             color = 'black')


# titles and labels
plt.title(label = "Immunization")
plt.xlabel(xlabel = '%')
plt.ylabel(ylabel = 'Frequency')


# New: These add vertical lines to the code
plt.axvline(x = cleaned_data_team7['Immunization'].mean(),
            color = 'red')


plt.axvline(x = cleaned_data_team7['Immunization'].median(),
            color = 'blue')


# this adds a legend
plt.legend(labels =  ['mean', 'median'])


# these compile and display the plot so that it is formatted as expected
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# setting figure size
fig, ax = plt.subplots(figsize = [8, 5])


# histogram for carat
sns.distplot(a     = cleaned_data_team7['Net ODA'],
             bins  = 3,   #to be changed if histogram shows gaps
             hist  = True,
             kde   = False,
             rug   = False,
             color = 'black')


# titles and labels
plt.title(label = "Net ODA")
plt.xlabel(xlabel = '%')
plt.ylabel(ylabel = 'Frequency')


# New: These add vertical lines to the code
plt.axvline(x = cleaned_data_team7['Net ODA'].mean(),
            color = 'red')


plt.axvline(x = cleaned_data_team7['Net ODA'].median(),
            color = 'blue')


# this adds a legend
plt.legend(labels =  ['mean', 'median'])


# these compile and display the plot so that it is formatted as expected
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# setting figure size
fig, ax = plt.subplots(figsize = [8, 5])


# histogram for carat
sns.distplot(a     = cleaned_data_team7['Population'],
             bins  = 3,   #to be changed if histogram shows gaps
             hist  = True,
             kde   = False,
             rug   = False,
             color = 'black')


# titles and labels
plt.title(label = "Population")
plt.xlabel(xlabel = '%')
plt.ylabel(ylabel = 'Frequency')


# New: These add vertical lines to the code
plt.axvline(x = cleaned_data_team7['Population'].mean(),
            color = 'red')


plt.axvline(x = cleaned_data_team7['Population'].median(),
            color = 'blue')


# this adds a legend
plt.legend(labels =  ['mean', 'median'])


# these compile and display the plot so that it is formatted as expected
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# setting figure size
fig, ax = plt.subplots(figsize = [8, 5])


# histogram for carat
sns.distplot(a     = cleaned_data_team7['Trade'],
             bins  = 4,   #to be changed if histogram shows gaps
             hist  = True,
             kde   = False,
             rug   = False,
             color = 'black')


# titles and labels
plt.title(label = "Trade")
plt.xlabel(xlabel = '%')
plt.ylabel(ylabel = 'Frequency')


# New: These add vertical lines to the code
plt.axvline(x = cleaned_data_team7['Trade'].mean(),
            color = 'red')


plt.axvline(x = cleaned_data_team7['Trade'].median(),
            color = 'blue')


# this adds a legend
plt.legend(labels =  ['mean', 'median'])


# these compile and display the plot so that it is formatted as expected
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# IMPUTING

# soft coding ... (MEDIAN OR MEAN) for COLUMN #1
carat_median = diamonds['COLUMN #1'].median().round(decimals = 2)   #change function depending if median or mean


# filling carat NAs with MEDIAN
diamonds['COLUMN #1'].fillna(value = carat_median,
                         inplace = True)


# checking to make sure NAs are filled in
print(diamonds['COLUMN #1'].isnull().any())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c52a84aa1a97> in <module>
#       2
#       3 # soft coding ... (MEDIAN OR MEAN) for COLUMN #1
# ----> 4 carat_median = diamonds['COLUMN #1'].median().round(decimals = 2)   #change function depending if median or mean
#       5
#       6
#
# NameError: name 'diamonds' is not defined

# %%
#OVERLAYING TO SEE IF IT MAKES SENSE

# setting figure size
fig, ax = plt.subplots(figsize = [8, 5],
                       sharex = True, # sharing x-axis between visualizations
                       sharey = True) # sharing y-axis between visualizations


# histogram for carat
sns.distplot(a     = df_dropped['COLUMN #1'],
             bins  = 21,
             hist  = True,
             kde   = True, # activating kde
             rug   = False,
             color = 'black')


# histogram for carat
sns.distplot(a     = diamonds['COLUMN #1'],
             bins  = 21,
             hist  = True,
             kde   = True, # activating kde
             rug   = False,
             color = 'gray')


# titles, labels, and formatting
plt.title(label   = "Distribution of COLUMN #1")
plt.xlabel(xlabel = 'COLUMN #1')
plt.ylabel(ylabel = 'Frequency')
plt.xlim(0.0, 2.75) # setting x-axis range
plt.ylim(0.0, 2.2) # setting y-axis range


# this adds a legend
plt.legend(labels =  ['original distribution',
                      'imputed distribution'])


# Saving a figure as an image
plt.savefig(fname = './analysis_images/Imputation of Carat.png')   #change location


# these compile and display the plot so that it is formatted as expected
plt.tight_layout()
plt.show()
